# %%
import gc
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
# %%time
train = pd.read_csv('./dataset/train.csv')
test = pd.read_csv('./dataset/test.csv')
# Out:
# Wall time: 19.5 s

# %%
print(list(train.columns))
# Out:
# ['Unnamed: 0', 'Unnamed: 0.1', 'TransactionID', 'isFraud', 'TransactionDT', 'TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2', 'P_emaildomain', 'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'D1', 'D10', 'D15', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30', 'V31', 'V32', 'V33', 'V34', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60', 'V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V90', 'V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V110', 'V111', 'V112', 'V113', 'V114', 'V115', 'V116', 'V117', 'V118', 'V119', 'V120', 'V121', 'V122', 'V123', 'V124', 'V1
# ...

# %%
cor_c = train[['hour', 'day','TransactionDT','TransactionAmt','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(8,8))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'addr1', 'addr2', 'P_emaildomain','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(12,12))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11', 'C12', 'C13', 'C14', 'D1', 'D10', 'D15','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'V29', 'V30','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V31', 'V32', 'V33', 'V34', 'V53', 'V54', 'V55', 'V56', 'V57', 'V58', 'V59', 'V60','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V61', 'V62', 'V63', 'V64', 'V65', 'V66', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72', 'V73', 'V74', 'V75', 'V76', 'V77', 'V78', 'V79', 'V80', 'V81', 'V82', 'V83', 'V84', 'V85', 'V86', 'V87', 'V88', 'V89', 'V90','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V91', 'V92', 'V93', 'V94', 'V95', 'V96', 'V97', 'V98', 'V99', 'V100', 'V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107', 'V108', 'V109', 'V110','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V111', 'V112', 'V113', 'V114', 'V115', 'V116', 'V117', 'V118', 'V119', 'V120', 'V121', 'V122', 'V123', 'V124', 'V125', 'V126', 'V127', 'V128', 'V129', 'V130', 'isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V130', 'V131', 'V132', 'V133', 'V134', 'V135', 'V136', 'V137', 'V279', 'V280', 'V281', 'V282', 'V283', 'V284', 'V285', 'V286', 'V287', 'V288', 'V289', 'V290','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V291', 'V292', 'V293', 'V294', 'V295', 'V296', 'V297', 'V298', 'V299', 'V300', 'V301', 'V302', 'V303', 'V304', 'V305', 'V306', 'V307', 'V308', 'V309', 'V310','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
cor_c = train[['V311', 'V312', 'V313', 'V314', 'V315', 'V316', 'V317', 'V318', 'V319', 'V320', 'V321','isFraud']]
f = cor_c.corr()

plt.figure(1,figsize=(18,18))
sns.heatmap(f,annot=True)
plt.show()

# %%
take = ['hour','TransactionDT','alertFeature','TransactionAmt','addr2','card5','card1', 'card3',
'D15','D10','D1','C1', 'C2','C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'C11']

dump = ['V21', 'V22','V28','V14', 'V25','V88', 'V89','V68','V101', 'V102', 'V103', 'V104', 'V105', 'V106', 'V107','V95', 'V96', 'V97','V130','V126', 'V127', 'V128','V130', 'V131', 'V132', 'V133', 'V134', 'V135', 'V136', 'V137', 'V279', 'V280','V305', 'V306', 'V307', 'V308','V291', 'V292', 'V293', 'V294', 'V295', 'V296', 'V297', 'V298', 'V299','V319']
dump2 = [ 'day', 'card4', 'card6', 'addr1', 'addr2', 'P_emaildomain','C3','C12', 'C13', 'C14', 'D1', 'D10', 'D15']

# %%
print(train.shape)
print(test.shape)
# Out:
# (590540, 187)
# (506691, 186)

# %%
train.drop(dump, axis=1, inplace=True)
test.drop(dump, axis=1, inplace=True)
print(train.shape)
print(test.shape)
# Out:
# (590540, 142)
# (506691, 141)

# %%
train.drop(dump2, axis=1, inplace=True)
test.drop(dump2, axis=1, inplace=True)
print(train.shape)
print(test.shape)
# Out:
# (590540, 129)
# (506691, 128)

# %%
# %%time
train.to_csv('./dataset/train.csv')
test.to_csv('./dataset/test.csv')
# Out:
# Wall time: 2min 3s
